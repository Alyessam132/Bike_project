# %%
import pandas as pd 
import numpy as np 
import json

# %%
df_chicago = pd.read_csv('chicago.csv')
df_1 = pd.read_csv('chicago.csv')
df_chicago['Start Time'] = df_chicago['Start Time'].astype('datetime64')
df_chicago['Month'] = df_chicago['Start Time'].dt.month_name()
df_chicago['Week Day'] = df_chicago['Start Time'].dt.day_name()
df_chicago['Hour'] = df_chicago['Start Time'].dt.hour
df_chicago_Month = df_chicago[df_chicago['Month'] == 'February']
df_chicago_Day = df_chicago_Month[df_chicago_Month['Week Day'] == 'Tuesday']
df_chicago_Day
# Out:
#         Unnamed: 0          Start Time             End Time  Trip Duration  \
# 147         273417 2017-02-28 07:39:05  2017-02-28 07:45:04            359
# 174         275028 2017-02-28 10:03:30  2017-02-28 10:16:45            795
# 243         175166 2017-02-14 21:03:32  2017-02-14 21:12:28            536
# 294         236346 2017-02-21 17:42:05  2017-02-21 17:50:49            524
# 398         234788 2017-02-21 16:35:11  2017-02-21 16:51:10            959
# ...            ...                 ...                  ...            ...
# 299527      170532 2017-02-14 09:12:18  2017-02-14 09:18:52            394
# 299620      174810 2017-02-14 19:09:43  2017-02-14 19:16:33            410
# 299646      277346 2017-02-28 16:57:01  2017-02-28 17:01:47            286
# 299708      168895 2017-02-14 06:34:50  2017-02-14 06:47:08            738
# 299904      137125 2017-02-07 08:12:07  2017-02-07 08:19:12            425
#
# ...

# %%
most_frequent_month = df_chicago['Month'].value_counts().idxmax() + ': ' + str(df_chicago['Month'].value_counts().max())
print(most_frequent_month)
print(df_chicago['Week Day'].value_counts().idxmax())
most_frequent_hour = str(df_chicago_Day['Hour'].value_counts().idxmax()) + ': ' + str(df_chicago_Day['Hour'].value_counts().max())
print(most_frequent_hour)
# Out:
# June: 98081
# Tuesday
# 17: 723

# %%
most_frequent_start = df_chicago_Day['Start Station'].value_counts().idxmax() + ': ' + str(df_chicago_Day['Start Station'].value_counts().max())
print(most_frequent_start)

most_frequent_end = df_chicago_Day['End Station'].value_counts().idxmax() + ': ' + str(df_chicago_Day['End Station'].value_counts().max())
print(most_frequent_end)
# Out:
# Clinton St & Washington Blvd: 122
# Clinton St & Washington Blvd: 110

# %%
df_chicago_Day['Trip'] = df_chicago_Day['Start Station'] + ', ' + df_chicago_Day['End Station']
df_chicago_Day['Trip'].value_counts()
# Out:
# <ipython-input-58-cc08da22ff61>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_chicago_Day["Trip"] = df_chicago_Day["Start Station"] + ", " + df_chicago_Day["End Station"]
# Columbus Dr & Randolph St, Clinton St & Washington Blvd           9
# State St & 33rd St, Calumet Ave & 33rd St                         8
# Wacker Dr & Washington St, Michigan Ave & Washington St           7
# Southport Ave & Wellington Ave, Sheffield Ave & Wellington Ave    7
# Clinton St & Washington Blvd, Michigan Ave & Lake St              6
#                                                                  ..
# Wabash Ave & Grand Ave, Canal St & Madison St                     1
# Streeter Dr & Grand Ave, Lake Shore Dr & Belmont Ave              1
# ...

# %%
print(df_chicago_Day['Trip Duration'].sum())
print(df_chicago_Day['Trip Duration'].mean())
# Out:
# 3415956
# 695.5723885155772

# %%
type_count = df_chicago_Day['User Type'].value_counts()

for i in range(len(type_count)) : 
    print(type_count.index[i] + ': ' + str(type_count[i]) + ', ' , end = '')
# Out:
# Subscriber: 4654, Customer: 257,

# %%
Gender_count = df_chicago_Day['Gender'].value_counts()

for i in range(len(type_count)) : 
    print(type_count.index[i] + ': ' + str(type_count[i]) + ', ' , end = '')
# Out:
# Subscriber: 4654, Customer: 257,

# %%
df_random = df_1.sample(5).to_dict(orient='records')

for item in df_random :
    print(json.dumps(item,indent =1 ))
# Out:
# {
#  "Unnamed: 0": 886013,
#  "Start Time": "2017-05-18 14:55:16",
#  "End Time": "2017-05-18 15:02:30",
#  "Trip Duration": 434,
#  "Start Station": "University Ave & 57th St",
#  "End Station": "Cottage Grove Ave & 51st St",
#  "User Type": "Subscriber",
#  "Gender": "Male",
#  "Birth Year": 1993.0
# }
# {
#  "Unnamed: 0": 317674,
#  "Start Time": "2017-03-08 08:34:56",
#  "End Time": "2017-03-08 08:54:22",
#  "Trip Duration": 1166,
#  "Start Station": "Ashland Ave & Grand Ave",
#  "End Station": "Mies van der Rohe Way & Chicago Ave",
#  "User Type": "Subscriber",
#  "Gender": "Female",
#  "Birth Year": 1985.0
# }
# {
#  "Unnamed: 0": 560681,
#  "Start Time": "2017-04-16 13:10:17",
#  "End Time": "2017-04-16 14:14:04",
#  "Trip Duration": 3827,
#  "Start Station": "Wells St & Concord Ln",
#  "End Station": "Lake Shore Dr & North Blvd",
#  "User Type": "Customer",
#  "Gender": NaN,
#  "Birth Year": NaN
# }
# {
#  "Unnamed: 0": 1878,
#  "Start Time": "2017-01-02 08:16:18",
# ...

# %%
df_chicago_Day.rename(columns={'population':'',}, inplace=True)
# Out:
# D:\anaconda\lib\site-packages\pandas\core\frame.py:4125: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %%
df_chicago['Gender'].mode()[0]
# Out:
# 'Male'

# %%
df_chicago['Month'] = df_chicago['Start Time'].dt.month
df_chicago
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-2d747b2a8631> in <module>
# ----> 1 df_chicago["Month"] = df_chicago["Start Time"].dt.month
#       2 df_chicago
#
# NameError: name 'df_chicago' is not defined

# %% [markdown]
# #### filter function

# %%
import time
import pandas as pd
import numpy as np
import json

# %% [markdown]
# #### filter data

# %%
CITY_DATA = { 'chicago': 'chicago.csv',
              'new york city': 'new_york_city.csv',
              'washington': 'washington.csv' }

time_filter_list = ['month', 'day', 'both', 'none']
month_list = ['january', 'february', 'march', 'april', 'may', 'june']
day_list = ['saturday', 'sunday', 'monday', 'tuesday', 'wednesday', 'thursday', 'friday']
time_filter = ''
city = ''

def get_filters():
    
    '''
    Asks user to specify a city, month, and day to analyze.

    Returns:
        (str) city - name of the city to analyze
        (str) month - name of the month to filter by, or 'all' to apply no month filter
        (str) day - name of the day of week to filter by, or 'all' to apply no day filter
    '''
    
    global city
    global time_filter
    
    print('Hello! Let\'s explore some US bikeshare data!')
    # TO DO: get user input for city (chicago, new york city, washington). HINT: Use a while loop to handle invalid inputs
    city = input('Would you like to see data for Chicago, New York City, or Washington?\n').lower()
    
    while city not in CITY_DATA.keys() :
        print('Invalid Value')
        city = input('Would you like to see data for Chicago, New York City, or Washington?\n').lower()

   
    time_filter = input('Would you like to filter the data by month, day, both, or not at all?\
    Type \'None\' for no time filter\n').lower()
    
    while time_filter not in time_filter_list :
        print('Invalid Value')
        time_filter = input('Would you like to filter the data by month, day, both, or not at all?\
    Type \'None\' for no time filter\n').lower()
        
    # TO DO: get user input for month (all, january, february, ... , june)
    if (time_filter == 'month') or  (time_filter == 'both') :
        month = input('Which Month? January, February, March, April, May, or June?\
        Please, type out the full month name\n').lower()
        
        while month not in month_list :
            print('Invalid Value')
            month = input('Which Month? January, February, March, April, May, or June?\
        Please, type out the full month name\n').lower()
            
    else :
        month = 'all'
    
    
    # TO DO: get user input for day of week (all, monday, tuesday, ... sunday)
    if (time_filter == 'day') or  (time_filter == 'both') :
        day = input('Which Day?  Please, type out the full day name\n').lower()
        
        while day not in day_list :
            print('Invalid Value')
            day = input('Which Day?  Please, type out the full day name\n').lower()
            
    else :
        day = 'all'

    print('-'*40)
    return city, month, day

# %% [markdown]
# #### Load Data Function

# %%
def load_data(city, month, day):
    
    '''
    Loads data for the specified city and filters by month and day if applicable.

    Args:
        (str) city - name of the city to analyze
        (str) month - name of the month to filter by, or 'all' to apply no month filter
        (str) day - name of the day of week to filter by, or 'all' to apply no day filter
    Returns:
        df - Pandas DataFrame containing city data filtered by month and day
    '''
    df = pd.read_csv(CITY_DATA[city])
    df['Start Time'] = df['Start Time'].astype('datetime64')
    df['Month'] = df['Start Time'].dt.month_name()
    df['Week Day'] = df['Start Time'].dt.day_name()
    
    
    if month != 'all' :
        df = df[df['Month'] == month.title()]
    
    if day != 'all' :
        df = df[df['Week Day'] == day.title()]

    return df

# %% [markdown]
# #### TIme Stats

# %%
def time_stats(df):
    """Displays statistics on the most frequent times of travel."""
    
    global time_filter
    
    print('\nCalculating The Most Frequent Times of Travel...\n')
    start_time = time.time()

    # TO DO: display the most common month
    month_count = df['Month'].value_counts()
    month_count_max = month_count.max()
    month_most_common = month_count.idxmax()
    
    if (time_filter == 'day') or (time_filter == 'none') :
        print('\nCalculating The Most Frequent Month of Travel...\n')
        print('Most Common Month: {}, Count: {}, Filter: {}'.format(month_most_common,month_count_max,time_filter))



    # TO DO: display the most common day of week
    week_day_count = df['Week Day'].value_counts()
    week_day_count_max = week_day_count.max()
    week_day_most_common = week_day_count.idxmax()
    
    if (time_filter == 'month') or (time_filter == 'none') :
        print('\nCalculating The Most Frequent Day of Travel...\n')
        print('Most Common Day: {}, Count: {}, Filter: {}'.format(week_day_most_common,week_day_count_max,time_filter))

    # TO DO: display the most common start hour
    df['Start Hour'] = df['Start Time'].dt.hour
    start_hour_count = df['Start Hour'].value_counts()
    start_hour_count_max = start_hour_count.max()
    start_hour_most_common = start_hour_count.idxmax()
    
    print('\nCalculating The Most Frequent Hour of Travel...\n')
    print('Most Common Start Hour: {}, Count: {}, Filter: {}'.format(start_hour_most_common,start_hour_count_max,time_filter))

    print('\nThis took %s seconds.' % (time.time() - start_time))
    print('-'*40)

# %% [markdown]
# #### Station Stats

# %%
def station_stats(df):
    """Displays statistics on the most popular stations and trip."""

    print('\nCalculating The Most Popular Stations and Trip...\n')
    start_time = time.time()

    # TO DO: display most commonly used start station
    start_station_count = df['Start Station'].value_counts()
    start_station_count_max = start_station_count.max()
    start_station_most_common = start_station_count.idxmax()
    
    print('\nCalculating The Most Start Station...\n')
    print('Most Common Start Station: {}, Count: {}'.format(start_station_most_common,start_station_count_max))
    
    # TO DO: display most commonly used end station
    end_station_count = df['End Station'].value_counts()
    end_station_count_max = end_station_count.max()
    end_station_most_common = end_station_count.idxmax()
    
    print('\nCalculating The Most Popular End Station...\n')
    print('Most Common End Station: {}, Count: {}'.format(end_station_most_common,end_station_count_max))

    # TO DO: display most frequent combination of start station and end station trip
    df['Trip'] = df['Start Station'] + ', ' + df['End Station']
    trip_count = df['Trip'].value_counts()
    trip_count_max = trip_count.max()
    trip_most_common = trip_count.idxmax()
    
    print('\nCalculating The Most Popular Trip...\n')
    print('Most Common Trip: {}, Count: {}'.format(trip_most_common,trip_count_max))

    print('\nThis took %s seconds.' % (time.time() - start_time))
    print('-'*40)

# %% [markdown]
# #### Trip duration Stats

# %%
def trip_duration_stats(df):
    """Displays statistics on the total and average trip duration."""

    print('\nCalculating Trip Duration...\n')
    start_time = time.time()

    # TO DO: display total travel time
    total_travel_time = df['Trip Duration'].sum()
    
    print('\nCalculating Total Trip Duration...\n')
    print('Total Travel Time: {}'.format(total_travel_time))

    # TO DO: display mean travel time
    print('\nCalculating Average Trip Duration...\n')
    average_travel_time = df['Trip Duration'].mean()
    print('Average Travel Time: {}'.format(average_travel_time))

    print('\nThis took %s seconds.' % (time.time() - start_time))
    print('-'*40)

# %% [markdown]
# #### User Stats

# %%
def user_stats(df):
    """Displays statistics on bikeshare users."""
    global city
    
    print('\nCalculating User Stats...\n')
    start_time = time.time()

    # TO DO: Display counts of user types
    
    print('\nCalculating User Types...\n')
    type_count = df['User Type'].value_counts()
    
    for i in range(len(type_count)) : 
        print ('{}: {}'.format(type_count.index[i],type_count[i]))


    # TO DO: Display counts of gender
    if city != 'washington' :
        
        print('\nCalculating User Gender...\n')
        gender_count = df['Gender'].value_counts()
        
        for i in range(len(gender_count)) : 
            print ('{}: {}'.format(gender_count.index[i],gender_count[i]))
        

    # TO DO: Display earliest, most recent, and most common year of birth
    if city != 'washington' :
        
        print('\nCalculating User Year of birth...\n')
        earliest_year = df['Birth Year'].min()
        most_recent_year = df['Birth Year'].max()
        most_common_year = df['Birth Year'].value_counts().idxmax()
        
        print('Earliest Year: {}'.format(earliest_year))
        print('Most Recent Year: {}'.format(most_recent_year))
        print('Most Common Year: {}'.format(most_common_year))
        

    print('\nThis took %s seconds.' % (time.time() - start_time))
    print('-'*40)

# %% [markdown]
# #### Display User Data

# %%
def display_user_data():
    """Displays data of five random users from the selected city and asking for input to display more random users."""
    global city
    df = pd.read_csv(CITY_DATA[city])
    df.rename(columns={'Unnamed: 0':'',}, inplace=True)
    df.fillna("Not Determined", inplace=True)
    
    df_random = df.sample(5).to_dict(orient='records')
    
    while True :
        
        print('\nDisplaying random individual trip data...\n')
        
        for item in df_random :
            print(json.dumps(item,indent =1 ))
            
        more_users = input('\nWould you like to view more individual trip data? Enter yes or no.\n').lower()
        
        if more_users != 'yes' :
            break

# %% [markdown]
# #### Main Function

# %%
def main():
    while True:
        
        city, month, day = get_filters()
        df = load_data(city, month, day)
        print(df)        
        time_stats(df)
        station_stats(df)
        trip_duration_stats(df)
        user_stats(df)
        display_user_data()

        restart = input('\nWould you like to restart? Enter yes or no.\n')
        if restart.lower() != 'yes':
            break


if __name__ == '__main__':
        main()
# Out:
# Hello! Let's explore some US bikeshare data!
# Would you like to see data for Chicago, New York City, or Washington?
# chicago
# Would you like to filter the data by month, day, both, or not at all?    Type 'None' for no time filter
# none
# ----------------------------------------
#         Unnamed: 0          Start Time             End Time  Trip Duration  \
# 0          1423854 2017-06-23 15:09:32  2017-06-23 15:14:53            321
# 1           955915 2017-05-25 18:19:03  2017-05-25 18:45:53           1610
# 2             9031 2017-01-04 08:27:49  2017-01-04 08:34:45            416
# 3           304487 2017-03-06 13:49:38  2017-03-06 13:55:28            350
# 4            45207 2017-01-17 14:53:07  2017-01-17 15:02:01            534
# ...            ...                 ...                  ...            ...
# 299995       64825 2017-01-21 13:18:00  2017-01-21 13:27:50            590
# 299996      695993 2017-04-28 19:32:19  2017-04-28 19:51:18           1139
# ...

# %% [markdown]
# #### All code
